# %%
import scipy as sp
import numpy as np
import pandas as pd
import sklearn
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import timedelta, datetime
import timeit


pd.options.display.max_rows = 4000

# %%
# Pulling data from ANRGUSC github
df = pd.read_csv('https://raw.githubusercontent.com/ANRGUSC/covid19_risk_estimation/master/data/Covid-19-R.csv')


# Converting String into Datetime data type
df['Time Stamp'] = pd.to_datetime(df['Time Stamp'])  


# Dropping Any Data with no Risk Score
df=df[df['Risk-Score']!=-1]

# %%
# renaming the first column to index

df=df.rename(columns={"Unnamed: 0": "index"})

# %%
df[df['Region']=='Arcadia'].sort_values('Time Stamp')
# Out:
#        index Time Stamp   Region   Latitude  Longitude  Risk-Score  Risk-Level
# 1          1 2020-03-16  Arcadia  34.136208 -118.04015    0.142132           1
# 32        32 2020-03-17  Arcadia  34.136208 -118.04015    0.053743           0
# 73        73 2020-03-18  Arcadia  34.136208 -118.04015    0.000000           0
# 118      118 2020-03-19  Arcadia  34.136208 -118.04015    0.000000           0
# 188      188 2020-03-20  Arcadia  34.136208 -118.04015    0.000000           0
# 270      270 2020-03-21  Arcadia  34.136208 -118.04015    0.170201           1
# 363      363 2020-03-22  Arcadia  34.136208 -118.04015    0.412967           1
# 465      465 2020-03-23  Arcadia  34.136208 -118.04015    0.649537           1
# 575      575 2020-03-24  Arcadia  34.136208 -118.04015    0.801244           1
# 698      698 2020-03-25  Arcadia  34.136208 -118.04015    0.842906           1
# 827      827 2020-03-26  Arcadia  34.136208 -118.04015    0.766758           1
# 974      974 2020-03-27  Arcadia  34.136208 -118.04015    0.611100           1
# 1201    1201 2020-03-28  Arcadia  34.136208 -118.04015    0.447638           1
# 1441    1441 2020-03-29  Arcadia  34.136208 -118.04015    0.338362           1
# 1681    1681 2020-03-30  Arcadia  34.136208 -118.04015    0.306257           1
# 1921    1921 2020-03-31  Arcadia  34.136208 -118.04015    0.313792           1
# 2161    2161 2020-04-01  Arcadia  34.136208 -118.04015    0.319350           1
# 4801    4801 2020-04-02  Arcadia  34.136208 -118.04015    0.315713           1
# 7351    7351 2020-04-03  Arcadia  34.136208 -118.04015    0.332104           1
# 7826    7826 2020-04-04  Arcadia  34.136208 -118.04015    0.370765           1
# 8066    8066 2020-04-05  Arcadia  34.136208 -118.04015    0.395465           1
# 8306    8306 2020-04-06  Arcadia  34.136208 -118.04015    0.371029           1
# 8546    8546 2020-04-07  Arcadia  34.136208 -118.04015    0.305708           1
# 8786    8786 2020-04-08  Arcadia  34.136208 -118.04015    0.271117           1
# 9026    9026 2020-04-09  Arcadia  34.136208 -118.04015    0.317992           1
# 2401    2401 2020-04-10  Arcadia  34.136208 -118.04015    0.431073           1
# 2641    2641 2020-04-11  Arcadia  34.136208 -118.04015    0.541253           1
# 2881    2881 2020-04-12  Arcadia  34.136208 -118.04015    0.585003           1
# 3121    3121 2020-04-13  Arcadia  34.136208 -118.04015    0.538128           1
# 3361    3361 2020-04-14  Arcadia  34.136208 -118.04015    0.420978           1
# 3601    3601 2020-04-15  Arcadia  34.136208 -118.04015    0.258551           1
# 3841    3841 2020-04-16  Arcadia  34.136208 -118.04015    0.073761           0
# 4081    4081 2020-04-17  Arcadia  34.136208 -118.04015    0.000000           0
# 4321    4321 2020-04-18  Arcadia  34.136208 -118.04015    0.000000           0
# 4561    4561 2020-04-19  Arcadia  34.136208 -118.04015    0.000000           0
# 15489  15489 2020-05-05  Arcadia  34.136208 -118.04015    8.126995           3
# 15728  15728 2020-05-06  Arcadia  34.136208 -118.04015    2.007317           3
# 15968  15968 2020-05-07  Arcadia  34.136208 -118.04015    0.000000           0
# 16208  16208 2020-05-08  Arcadia  34.136208 -118.04015    0.000000           0
# 16448  16448 2020-05-09  Arcadia  34.136208 -118.04015    0.000000           0
# 9502    9502 2020-05-10  Arcadia  34.136208 -118.04015    0.000000           0
# 9742    9742 2020-05-11  Arcadia  34.136208 -118.04015    0.129291           1
# 9982    9982 2020-05-12  Arcadia  34.136208 -118.04015    0.967825           1
# 10222  10222 2020-05-13  Arcadia  34.136208 -118.04015    0.719404           1
# 10462  10462 2020-05-14  Arcadia  34.136208 -118.04015    0.084146           0
# 10702  10702 2020-05-15  Arcadia  34.136208 -118.04015    0.000000           0
# 10942  10942 2020-05-16  Arcadia  34.136208 -118.04015    0.000000           0
# 11182  11182 2020-05-17  Arcadia  34.136208 -118.04015    0.000000           0
# 11422  11422 2020-05-18  Arcadia  34.136208 -118.04015    0.171826           1
# 11662  11662 2020-05-19  Arcadia  34.136208 -118.04015    0.523088           1
# 12138  12138 2020-05-20  Arcadia  34.136208 -118.04015    0.757202           1
# 12378  12378 2020-05-21  Arcadia  34.136208 -118.04015    0.914394           1
# 12618  12618 2020-05-22  Arcadia  34.136208 -118.04015    1.092955           2
# 12858  12858 2020-05-23  Arcadia  34.136208 -118.04015    1.286310           2
# 13098  13098 2020-05-24  Arcadia  34.136208 -118.04015    1.364777           2
# 13338  13338 2020-05-25  Arcadia  34.136208 -118.04015    1.202567           2
# 13578  13578 2020-05-26  Arcadia  34.136208 -118.04015    0.866292           1
# 13818  13818 2020-05-27  Arcadia  34.136208 -118.04015    0.552978           1
# 14058  14058 2020-05-28  Arcadia  34.136208 -118.04015    0.502820           1
# 14298  14298 2020-05-29  Arcadia  34.136208 -118.04015    0.713672           1
# 14774  14774 2020-05-30  Arcadia  34.136208 -118.04015    0.978694           1
# 15014  15014 2020-05-31  Arcadia  34.136208 -118.04015    1.079988           2
# 16688  16688 2020-06-01  Arcadia  34.136208 -118.04015    0.900226           1
# 19328  19328 2020-06-02  Arcadia  34.136208 -118.04015    0.574797           1
# 21968  21968 2020-06-03  Arcadia  34.136208 -118.04015    0.282376           1
# 22448  22448 2020-06-04  Arcadia  34.136208 -118.04015    0.146133           1
# 22688  22688 2020-06-05  Arcadia  34.136208 -118.04015    0.186414           1
# 22928  22928 2020-06-06  Arcadia  34.136208 -118.04015    0.317754           1
# 23168  23168 2020-06-07  Arcadia  34.136208 -118.04015    0.442819           1
# 23408  23408 2020-06-08  Arcadia  34.136208 -118.04015    0.501678           1
# 23648  23648 2020-06-09  Arcadia  34.136208 -118.04015    0.459756           1
# 16928  16928 2020-06-10  Arcadia  34.136208 -118.04015    0.359127           1
# 17168  17168 2020-06-11  Arcadia  34.136208 -118.04015    0.282217           1
# 17408  17408 2020-06-12  Arcadia  34.136208 -118.04015    0.368621           1
# 17648  17648 2020-06-13  Arcadia  34.136208 -118.04015    0.780423           1
# 17888  17888 2020-06-14  Arcadia  34.136208 -118.04015    1.521382           2
# 18128  18128 2020-06-15  Arcadia  34.136208 -118.04015    2.403450           3
# 18368  18368 2020-06-16  Arcadia  34.136208 -118.04015    2.995283           3
# 18608  18608 2020-06-17  Arcadia  34.136208 -118.04015    2.920716           3
# 18848  18848 2020-06-18  Arcadia  34.136208 -118.04015    2.204315           3
# 19088  19088 2020-06-19  Arcadia  34.136208 -118.04015    1.199266           2
# 19568  19568 2020-06-20  Arcadia  34.136208 -118.04015    0.475891           1
# 19808  19808 2020-06-21  Arcadia  34.136208 -118.04015    0.306095           1
# 20048  20048 2020-06-22  Arcadia  34.136208 -118.04015    0.629988           1
# 20288  20288 2020-06-23  Arcadia  34.136208 -118.04015    1.213069           2
# 20528  20528 2020-06-24  Arcadia  34.136208 -118.04015    1.800227           2
# 20768  20768 2020-06-25  Arcadia  34.136208 -118.04015    2.265006           3
# 21008  21008 2020-06-26  Arcadia  34.136208 -118.04015    2.480822           3
# 21248  21248 2020-06-27  Arcadia  34.136208 -118.04015    2.332321           3
# 21488  21488 2020-06-28  Arcadia  34.136208 -118.04015    1.895887           2
# 21728  21728 2020-06-29  Arcadia  34.136208 -118.04015    1.382063           2
# 22208  22208 2020-06-30  Arcadia  34.136208 -118.04015    1.074031           2
# 23888  23888 2020-07-01  Arcadia  34.136208 -118.04015    1.130288           2
# 26524  26524 2020-07-02  Arcadia  34.136208 -118.04015    1.473088           2
# 29160  29160 2020-07-03  Arcadia  34.136208 -118.04015    1.935413           2
# 29880  29880 2020-07-04  Arcadia  34.136208 -118.04015    2.295775           3
# 30120  30120 2020-07-05  Arcadia  34.136208 -118.04015    2.406256           3
# 30360  30360 2020-07-06  Arcadia  34.136208 -118.04015    2.211215           3
# 30600  30600 2020-07-07  Arcadia  34.136208 -118.04015    1.843821           2
# 30840  30840 2020-07-08  Arcadia  34.136208 -118.04015    1.535093           2
# 31080  31080 2020-07-09  Arcadia  34.136208 -118.04015    1.453119           2
# 24128  24128 2020-07-10  Arcadia  34.136208 -118.04015    1.547781           2
# 24368  24368 2020-07-11  Arcadia  34.136208 -118.04015    1.594131           2
# 24608  24608 2020-07-12  Arcadia  34.136208 -118.04015    1.503568           2
# 24848  24848 2020-07-13  Arcadia  34.136208 -118.04015    1.399589           2
# 25088  25088 2020-07-14  Arcadia  34.136208 -118.04015    1.495419           2
# 25328  25328 2020-07-15  Arcadia  34.136208 -118.04015    1.849627           2
# 25567  25567 2020-07-16  Arcadia  34.136208 -118.04015    2.193593           3
# 25806  25806 2020-07-17  Arcadia  34.136208 -118.04015    2.236119           3
# 26045  26045 2020-07-18  Arcadia  34.136208 -118.04015    1.875474           2
# 26284  26284 2020-07-19  Arcadia  34.136208 -118.04015    1.293877           2
# 26763  26763 2020-07-20  Arcadia  34.136208 -118.04015    0.840350           1
# 27003  27003 2020-07-21  Arcadia  34.136208 -118.04015    0.742922           1
# 27242  27242 2020-07-22  Arcadia  34.136208 -118.04015    1.049428           2
# 27481  27481 2020-07-23  Arcadia  34.136208 -118.04015    1.573662           2
# 27720  27720 2020-07-24  Arcadia  34.136208 -118.04015    2.043488           3
# 27960  27960 2020-07-25  Arcadia  34.136208 -118.04015    2.210075           3
# 28200  28200 2020-07-26  Arcadia  34.136208 -118.04015    2.034554           3
# 28440  28440 2020-07-27  Arcadia  34.136208 -118.04015    1.750109           2
# 28680  28680 2020-07-28  Arcadia  34.136208 -118.04015    1.681315           2
# 28920  28920 2020-07-29  Arcadia  34.136208 -118.04015    2.133738           3
# 29400  29400 2020-07-30  Arcadia  34.136208 -118.04015    2.934927           3
# 29640  29640 2020-07-31  Arcadia  34.136208 -118.04015    3.707859           3
# 31320  31320 2020-08-01  Arcadia  34.136208 -118.04015    4.039583           3
# 31560  31560 2020-08-02  Arcadia  34.136208 -118.04015    3.811668           3
# 31800  31800 2020-08-03  Arcadia  34.136208 -118.04015    3.380265           3
# 32040  32040 2020-08-04  Arcadia  34.136208 -118.04015    3.037390           3
# 32280  32280 2020-08-05  Arcadia  34.136208 -118.04015    2.997440           3
# 32520  32520 2020-08-06  Arcadia  34.136208 -118.04015    3.117760           3
# 32760  32760 2020-08-07  Arcadia  34.136208 -118.04015    3.212682           3
# 33000  33000 2020-08-08  Arcadia  34.136208 -118.04015    3.242215           3

# %%
# start_time = timeit.default_timer()


# This function calculates trend of the Risk-Score overtime.
# Input:  area:               this can be either 'all' or specific name of the region
#         length1, length2:   these parameters define the windows of the rolling/moving average
# Output: df_updated:         this new dataframe contains new rolling averages, and risk-score difference in addition to original data

def calc_risk_trend(area, length1, length2):
    df_recent_1= pd.DataFrame()
    df_recent_2= pd.DataFrame()
    df_rolling_1= pd.DataFrame()
    df_rolling_2= pd.DataFrame()
    rs_diff_3 = []
    rs_diff_7 = []
    
    if area == 'all': # if 'all' is given, iterate through all regions in the data
        regions = df['Region'].unique()
        df_new = df.copy()
    else:
        regions = [area]
        df_new = df[df['Region']==area]


    for region in regions:
        df_region = df_new[df_new['Region']==region].sort_values('Time Stamp')
        
        
        # defining specific dates that we are going to pull data from
        recent_date = max(df_region['Time Stamp'])
        length1_bef = pd.to_datetime(recent_date) - dt.timedelta(days=length1)
        length2_bef = pd.to_datetime(recent_date) - dt.timedelta(days=length2)
        
        # pulling data matching dates defined
        df_1_before = df_region[df_region['Time Stamp'] == length1_bef]
        df_2_before = df_region[df_region['Time Stamp'] == length2_bef]
        df_recent = df_region[df_region['Time Stamp']==recent_date]
        
        
        
        
        string1= "RS_change_{}".format(length1)
        string2= "RS_change_{}".format(length2)
        
        # calculating the Risk-Score difference between most current data to the past data
        if not df_1_before['Risk-Score'].empty:
            df_recent[string1] = df_recent['Risk-Score'].iloc[0]-df_1_before['Risk-Score'].iloc[0]
        else:
            df_recent[string1] = df_recent['Risk-Score'].iloc[0]

        if not df_2_before['Risk-Score'].empty:
            df_recent[string2] = df_recent['Risk-Score'].iloc[0]-df_2_before['Risk-Score'].iloc[0]
        else:
            df_recent[string2] = df_recent['Risk-Score'].iloc[0]
        
        df_recent_1 = df_recent_1.append(df_recent[['index',string1]]) # adding the differences to a list
        df_recent_2 = df_recent_2.append(df_recent[['index',string2]])



        # calculating rolling averages
        rolling_rs_1 = df_region['Risk-Score'].rolling(length1, min_periods=1).mean()
        rolling_rs_2 = df_region['Risk-Score'].rolling(length2, min_periods=1).mean()
#         rolling_rs_1 = df_region['Risk-Score'].ewm(span=length1, adjust=False).mean() #this is for exponential rolling average
#         rolling_rs_2 = df_region['Risk-Score'].ewm(span=length2, adjust=False).mean()

        
        df_rolling_1 = df_rolling_1.append(rolling_rs_1)
        df_rolling_2 = df_rolling_2.append(rolling_rs_2)
        


    
    
#     df_updated = pd.merge(left=df_new, right=df_recent_1, how='left', on='index')
    df_updated = df_new.merge(df_recent_1, left_index=True, right_index=True, how='left')
    df_updated = df_updated.merge(df_recent_2, left_index=True, right_index=True, how='left')
#     df_updated = pd.merge(left=df_updated, right=df_recent_2, how='left', on='index')
    
    df_rolling_1_sum = df_rolling_1.sum(skipna = True, axis=0)
    df_rolling_2_sum = df_rolling_2.sum(skipna = True, axis=0)

    rolling_1 = pd.DataFrame()
    rolling_2 = pd.DataFrame()
    
    string3 = "Rolling Average {} Days".format(length1)
    string4 = "Rolling Average {} Days".format(length2)
    
    rolling_1[string3]=df_rolling_1_sum
    rolling_2[string4]=df_rolling_2_sum
    
    df_updated = df_updated.merge(rolling_1, left_index=True, right_index=True, how='left')
    df_updated = df_updated.merge(rolling_2, left_index=True, right_index=True, how='left')
    
    df_updated = df_updated.sort_values('Time Stamp')
    
    
    
    return df_updated

# elapsed = timeit.default_timer() - start_time
# print(elapsed)

# %%
# this function uses calc_risk_trend function to calculate the rolling average and creates a time-series plot
# thsi function only works when a specific region is given

def plot_rs(city_name,length1,length2):
    df_final = calc_risk_trend(city_name, length1, length2)
    df_a = df[df['Region']==city_name].sort_values('Time Stamp')
    plt.figure(figsize=(15,10)) 




    string3 = "Rolling Average {} Days".format(length1)
    string4 = "Rolling Average {} Days".format(length2)

    plt.plot('Time Stamp','Risk-Score',marker='o', data =df_a, color='black')
    plt.plot('Time Stamp',string3, marker='o', data =df_final, color='red')
    plt.plot('Time Stamp',string4, marker='o', data =df_final, color='blue')




    plt.legend()
    plt.xticks(rotation=90)
    plt.xlabel('Date')
    plt.ylabel('Risk Score')
    plt.title('Risk Score of ' + city_name)
    
    
    y_max=max(df_final['Risk-Score'])
    y_max=y_max+y_max/10

    plt.axhspan(0,1, color='green', alpha=0.1)
    plt.axhspan(1,2, color='yellow', alpha=0.1)
    plt.axhspan(2,y_max+10, color='red', alpha=0.1)
    plt.ylim(0,y_max)
    plt.grid()

    
    plt.show()

# %%
# In order to find out how Risk-Level was defined, I used code below:

score1=df[df['Risk-Level']==1]['Risk-Score']
score2=df[df['Risk-Level']==2]['Risk-Score']
score3=df[df['Risk-Level']==3]['Risk-Score']
print(max(score2))
print(min(score3))

# Looks like level 1 is given to risk score of 0~1, level 2 is given to risk score of 1~2, and level 3 to risk score greater than 2.
# Out:
# 1.9997663368834293
# 2.000270302927293

# %%
# List of all the regions in the data

df['Region'].unique()
# Out:
# array(['Alhambra', 'Arcadia', 'Beverly Hills', 'Boyle Heights', 'Carson',
#        'Diamond Bar', 'Encino', 'Gardena', 'Glendale', 'Glendora',
#        'Granada Hills', 'Inglewood', 'La Mirada', 'Lancaster',
#        'Manhattan Beach', 'Melrose', 'Northridge', 'San Dimas',
#        'San Pedro', 'Santa Monica', 'Sherman Oaks', 'Silverlake',
#        'Tarzana', 'Torrance', 'Venice', 'West Adams', 'West Hills',
#        'West Hollywood', 'West Vernon', 'Westchester', 'Altadena',
#        'Baldwin Hills', 'Brentwood', 'Culver City', 'Eagle Rock',
#        'Hollywood', 'Hollywood Hills', 'Lynwood', 'Mar Vista',
#        'Monterey Park', 'North Hollywood', 'Reseda', 'Santa Clarita',
#        'Woodland Hills', 'Century Palms/Cove', 'Sylmar', 'Walnut',
#        'West Los Angeles', 'Beverlywood', 'Burbank', 'Calabasas',
#        'Castaic', 'Covina', 'Crestview', 'East Los Angeles', 'Echo Park',
#        'Hancock Park', 'Hawthorne', 'Lawndale', 'Lomita',
#        'Pacific Palisades', 'Palms', 'Playa Vista',
#        'Santa Monica Mountains', 'South El Monte', 'Studio City',
#        'Tujunga', 'University Park', 'Valley Glen', 'Van Nuys',
#        'Vermont Knolls', 'Westwood', 'Whittier', 'Century City',
#        'El Segundo', 'Lake Balboa', 'Lakewood', 'Miracle Mile',
#        'Park La Brea', 'Redondo Beach', 'San Fernando', 'South Whittier',
#        'Winnetka', 'Del Rey', 'La Canada Flintridge', 'La Verne',
#        'Montebello', 'Sun Valley', 'Sunland', 'Vermont Vista',
#        'Vernon Central', 'West Covina', 'Westlake', 'Athens',
#        'Bellflower', 'Canoga Park', 'East Hollywood', 'Los Feliz',
#        'Paramount', 'Rancho Palos Verdes', 'South Gate', 'Agoura Hills',
#        'Duarte', 'Exposition Park', 'Florence', 'Hyde Park',
#        'Lincoln Heights', 'Palmdale', 'South Park', 'Wilshire Center',
#        'Canyon Country', 'Claremont', 'Downey', 'Harbor Gateway',
#        'Harvard Heights', 'Highland Park', 'La Puente', 'Norwalk',
#        'Pico Rivera', 'Porter Ranch', 'San Gabriel', 'Wholesale District',
#        'Willowbrook', 'Arleta', 'Bell Gardens', 'Crenshaw District',
#        'Glassell Park', 'Panorama City', 'Pomona', 'Valinda', 'Watts',
#        'Azusa', 'Bell', 'Chatsworth', 'Hacienda Heights', 'Harbor City',
#        'Leimert Park', 'Little Bangladesh', 'Maywood', 'Monrovia',
#        'North Hills', 'Pacoima', 'Acton', 'Adams-Normandie', 'Alsace',
#        'Angelino Heights', 'Artesia', 'Atwater Village', 'Avalon',
#        'Baldwin Park', 'Bassett', 'Bel Air', 'Beverly Crest', 'Bradbury',
#        'Brookside', 'Cadillac-Corning', 'Carthay', 'Central',
#        'Cheviot Hills', 'Commerce', 'Compton', 'Country Club Park',
#        'Cudahy', 'El Monte', 'El Sereno', 'Elysian Park',
#        'Elysian Valley', 'Exposition', 'Faircrest Heights',
#        'Figueroa Park Square', 'Florence-Firestone', 'Gramercy Place',
#        'Green Meadows', 'Harbor Pines', 'Harvard Park',
#        'Hawaiian Gardens', 'Hermosa Beach', 'Hidden Hills', 'Industry',
#        'Irwindale', 'Jefferson Park', 'La Habra Heights',
#        'Lafayette Square', 'Lake Los Angeles', 'Lakeview Terrace',
#        'Little Armenia', 'Little Tokyo', 'Longwood', 'Malibu',
#        'Manchester Square', 'Mandeville Canyon', 'Marina Peninsula',
#        'Mid-city', 'Mission Hills', 'Palisades Highlands',
#        'Palos Verdes Estates', 'Pasadena', 'Pico-Union', 'Playa Del Rey',
#        'Rancho Park', 'Regent Square', 'Reseda Ranch', 'Reynier Village',
#        'Rolling Hills', 'Rolling Hills Estates', 'Rosemead',
#        'Rowland Heights', 'San Marino', 'Santa Fe Springs',
#        'Shadow Hills', 'Sierra Madre', 'Signal Hill', 'South Carthay',
#        'St Elmo Village', 'Sycamore Square', 'Temple City',
#        'Temple-Beaudry', 'Thai Town', 'Toluca Lake', 'Toluca Terrace',
#        'Toluca Woods', 'University Hills', 'Valley Village',
#        'Vermont Square', 'Vernon', 'View Heights', 'Westlake Village',
#        'Angeles National Forest', 'Cerritos', 'Chinatown',
#        'Cloverdale/Cochran', 'Downtown', 'Historic Filipinotown',
#        'Huntington Park', 'Koreatown', 'Mt. Washington', 'South Pasadena',
#        'Victoria Park', 'Wellington Square', 'West Whittier/Los Nietos',
#        'Wilmington'], dtype=object)

# %%
plot_rs('Santa Monica',12, 24)
# Out:
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plot_rs('Hollywood',14, 30)
# Out:
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plot_rs('Wilmington',7, 30)
calc_risk_trend('Wilmington', 7, 30)
# Out:
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        index_x Time Stamp      Region   Latitude   Longitude  Risk-Score  \
# 1429      1429 2020-03-28  Wilmington  33.780016 -118.262509    1.955186
# 1669      1669 2020-03-29  Wilmington  33.780016 -118.262509    1.200722
# 1909      1909 2020-03-30  Wilmington  33.780016 -118.262509    0.441217
# 2149      2149 2020-03-31  Wilmington  33.780016 -118.262509    0.043317
# 2389      2389 2020-04-01  Wilmington  33.780016 -118.262509    0.085823
# 5029      5029 2020-04-02  Wilmington  33.780016 -118.262509    0.330908
# 7579      7579 2020-04-03  Wilmington  33.780016 -118.262509    0.467090
# 8054      8054 2020-04-04  Wilmington  33.780016 -118.262509    0.418479
# 8294      8294 2020-04-05  Wilmington  33.780016 -118.262509    0.321108
# 8534      8534 2020-04-06  Wilmington  33.780016 -118.262509    0.382886
# 8774      8774 2020-04-07  Wilmington  33.780016 -118.262509    0.664463
# 9014      9014 2020-04-08  Wilmington  33.780016 -118.262509    1.012551
# 9254      9254 2020-04-09  Wilmington  33.780016 -118.262509    1.219225
# 2629      2629 2020-04-10  Wilmington  33.780016 -118.262509    1.187695
# 2869      2869 2020-04-11  Wilmington  33.780016 -118.262509    1.055173
# 3109      3109 2020-04-12  Wilmington  33.780016 -118.262509    1.036863
# 3349      3349 2020-04-13  Wilmington  33.780016 -118.262509    1.238018
# 3589      3589 2020-04-14  Wilmington  33.780016 -118.262509    1.566848
# 3829      3829 2020-04-15  Wilmington  33.780016 -118.262509    1.874869
# 4069      4069 2020-04-16  Wilmington  33.780016 -118.262509    2.030640
# 4309      4309 2020-04-17  Wilmington  33.780016 -118.262509    2.062847
# 4549      4549 2020-04-18  Wilmington  33.780016 -118.262509    1.988292
# 4789      4789 2020-04-19  Wilmington  33.780016 -118.262509    1.832821
# 5258      5258 2020-04-20  Wilmington  33.780016 -118.262509    1.643801
# 5487      5487 2020-04-21  Wilmington  33.780016 -118.262509    1.457826
# 5716      5716 2020-04-22  Wilmington  33.780016 -118.262509    1.402597
# 5945      5945 2020-04-23  Wilmington  33.780016 -118.262509    1.481735
# 6175      6175 2020-04-24  Wilmington  33.780016 -118.262509    1.628407
# 6406      6406 2020-04-25  Wilmington  33.780016 -118.262509    1.758991
# 6639      6639 2020-04-26  Wilmington  33.780016 -118.262509    1.785640
# 6872      6872 2020-04-27  Wilmington  33.780016 -118.262509    1.689698
# 7105      7105 2020-04-28  Wilmington  33.780016 -118.262509    1.538053
# 7339      7339 2020-04-29  Wilmington  33.780016 -118.262509    1.393132
# 7814      7814 2020-04-30  Wilmington  33.780016 -118.262509    1.397029
# 9490      9490 2020-05-01  Wilmington  33.780016 -118.262509    1.676352
# 12126    12126 2020-05-02  Wilmington  33.780016 -118.262509    2.144939
# 14762    14762 2020-05-03  Wilmington  33.780016 -118.262509    2.575104
# 15479    15479 2020-05-04  Wilmington  33.780016 -118.262509    2.534284
# 15717    15717 2020-05-05  Wilmington  33.780016 -118.262509    1.903093
# 15956    15956 2020-05-06  Wilmington  33.780016 -118.262509    0.911590
# 16196    16196 2020-05-07  Wilmington  33.780016 -118.262509    0.038685
# 16436    16436 2020-05-08  Wilmington  33.780016 -118.262509    0.000000
# 16676    16676 2020-05-09  Wilmington  33.780016 -118.262509    0.000000
# 9730      9730 2020-05-10  Wilmington  33.780016 -118.262509    0.327455
# 9970      9970 2020-05-11  Wilmington  33.780016 -118.262509    0.775208
# 10210    10210 2020-05-12  Wilmington  33.780016 -118.262509    1.157938
# 10450    10450 2020-05-13  Wilmington  33.780016 -118.262509    1.529576
# 10690    10690 2020-05-14  Wilmington  33.780016 -118.262509    1.865520
# 10930    10930 2020-05-15  Wilmington  33.780016 -118.262509    2.115312
# 11170    11170 2020-05-16  Wilmington  33.780016 -118.262509    2.266454
# 11410    11410 2020-05-17  Wilmington  33.780016 -118.262509    2.407841
# 11650    11650 2020-05-18  Wilmington  33.780016 -118.262509    2.717781
# 11890    11890 2020-05-19  Wilmington  33.780016 -118.262509    3.173903
# 12366    12366 2020-05-20  Wilmington  33.780016 -118.262509    3.691069
# 12606    12606 2020-05-21  Wilmington  33.780016 -118.262509    4.159015
# 12846    12846 2020-05-22  Wilmington  33.780016 -118.262509    4.521073
# 13086    13086 2020-05-23  Wilmington  33.780016 -118.262509    4.731039
# 13326    13326 2020-05-24  Wilmington  33.780016 -118.262509    4.690914
# 13566    13566 2020-05-25  Wilmington  33.780016 -118.262509    4.409293
# 13806    13806 2020-05-26  Wilmington  33.780016 -118.262509    4.225878
# 14046    14046 2020-05-27  Wilmington  33.780016 -118.262509    4.541699
# 14286    14286 2020-05-28  Wilmington  33.780016 -118.262509    5.270643
# 14526    14526 2020-05-29  Wilmington  33.780016 -118.262509    5.765724
# 15002    15002 2020-05-30  Wilmington  33.780016 -118.262509    5.138000
# 15242    15242 2020-05-31  Wilmington  33.780016 -118.262509    3.302851
# 16916    16916 2020-06-01  Wilmington  33.780016 -118.262509    1.116140
# 19556    19556 2020-06-02  Wilmington  33.780016 -118.262509    0.000000
# 22196    22196 2020-06-03  Wilmington  33.780016 -118.262509    0.000000
# 22676    22676 2020-06-04  Wilmington  33.780016 -118.262509    1.096559
# 22916    22916 2020-06-05  Wilmington  33.780016 -118.262509    2.512148
# 23156    23156 2020-06-06  Wilmington  33.780016 -118.262509    3.386220
# 23396    23396 2020-06-07  Wilmington  33.780016 -118.262509    3.640138
# 23636    23636 2020-06-08  Wilmington  33.780016 -118.262509    3.582935
# 23876    23876 2020-06-09  Wilmington  33.780016 -118.262509    3.620099
# 17156    17156 2020-06-10  Wilmington  33.780016 -118.262509    3.798998
# 17396    17396 2020-06-11  Wilmington  33.780016 -118.262509    3.812458
# 17636    17636 2020-06-12  Wilmington  33.780016 -118.262509    3.375212
# 17876    17876 2020-06-13  Wilmington  33.780016 -118.262509    2.493587
# 18116    18116 2020-06-14  Wilmington  33.780016 -118.262509    1.690280
# 18356    18356 2020-06-15  Wilmington  33.780016 -118.262509    1.621990
# 18596    18596 2020-06-16  Wilmington  33.780016 -118.262509    2.634472
# 18836    18836 2020-06-17  Wilmington  33.780016 -118.262509    4.377827
# 19076    19076 2020-06-18  Wilmington  33.780016 -118.262509    6.057321
# 19316    19316 2020-06-19  Wilmington  33.780016 -118.262509    6.810028
# 19796    19796 2020-06-20  Wilmington  33.780016 -118.262509    6.381040
# 20036    20036 2020-06-21  Wilmington  33.780016 -118.262509    5.096460
# 20276    20276 2020-06-22  Wilmington  33.780016 -118.262509    3.623268
# 20516    20516 2020-06-23  Wilmington  33.780016 -118.262509    2.736859
# 20756    20756 2020-06-24  Wilmington  33.780016 -118.262509    2.860294
# 20996    20996 2020-06-25  Wilmington  33.780016 -118.262509    4.215892
# 21236    21236 2020-06-26  Wilmington  33.780016 -118.262509    6.342357
# 21476    21476 2020-06-27  Wilmington  33.780016 -118.262509    8.455828
# 21716    21716 2020-06-28  Wilmington  33.780016 -118.262509    9.545963
# 21956    21956 2020-06-29  Wilmington  33.780016 -118.262509    9.034221
# 22436    22436 2020-06-30  Wilmington  33.780016 -118.262509    7.347523
# 24116    24116 2020-07-01  Wilmington  33.780016 -118.262509    5.391187
# 26752    26752 2020-07-02  Wilmington  33.780016 -118.262509    4.268262
# 29388    29388 2020-07-03  Wilmington  33.780016 -118.262509    4.302113
# 30108    30108 2020-07-04  Wilmington  33.780016 -118.262509    5.135388
# 30348    30348 2020-07-05  Wilmington  33.780016 -118.262509    6.104849
# 30588    30588 2020-07-06  Wilmington  33.780016 -118.262509    6.758255
# 30828    30828 2020-07-07  Wilmington  33.780016 -118.262509    7.219506
# 31068    31068 2020-07-08  Wilmington  33.780016 -118.262509    7.871218
# 31308    31308 2020-07-09  Wilmington  33.780016 -118.262509    8.894554
# 24356    24356 2020-07-10  Wilmington  33.780016 -118.262509    9.921852
# 24596    24596 2020-07-11  Wilmington  33.780016 -118.262509   10.260729
# 24836    24836 2020-07-12  Wilmington  33.780016 -118.262509    9.437105
# 25076    25076 2020-07-13  Wilmington  33.780016 -118.262509    7.610170
# 25316    25316 2020-07-14  Wilmington  33.780016 -118.262509    5.570958
# 25556    25556 2020-07-15  Wilmington  33.780016 -118.262509    4.140241
# 25795    25795 2020-07-16  Wilmington  33.780016 -118.262509    3.722597
# 26034    26034 2020-07-17  Wilmington  33.780016 -118.262509    4.177642
# 26273    26273 2020-07-18  Wilmington  33.780016 -118.262509    4.909879
# 26512    26512 2020-07-19  Wilmington  33.780016 -118.262509    5.451844
# 26991    26991 2020-07-20  Wilmington  33.780016 -118.262509    5.593844
# 27231    27231 2020-07-21  Wilmington  33.780016 -118.262509    5.452433
# 27470    27470 2020-07-22  Wilmington  33.780016 -118.262509    5.454962
# 27709    27709 2020-07-23  Wilmington  33.780016 -118.262509    5.554390
# 27948    27948 2020-07-24  Wilmington  33.780016 -118.262509    5.629304
# 28188    28188 2020-07-25  Wilmington  33.780016 -118.262509    5.580394
# 28428    28428 2020-07-26  Wilmington  33.780016 -118.262509    5.592521
# 28668    28668 2020-07-27  Wilmington  33.780016 -118.262509    6.159578
# 28908    28908 2020-07-28  Wilmington  33.780016 -118.262509    7.043943
# 29148    29148 2020-07-29  Wilmington  33.780016 -118.262509    7.550857
# 29628    29628 2020-07-30  Wilmington  33.780016 -118.262509    6.870441
# 29868    29868 2020-07-31  Wilmington  33.780016 -118.262509    4.938602
# 31548    31548 2020-08-01  Wilmington  33.780016 -118.262509    3.123467
# 31788    31788 2020-08-02  Wilmington  33.780016 -118.262509    2.957609
# 32028    32028 2020-08-03  Wilmington  33.780016 -118.262509    5.417978
# 32268    32268 2020-08-04  Wilmington  33.780016 -118.262509    9.700377
# 32508    32508 2020-08-05  Wilmington  33.780016 -118.262509   13.786341
# 32748    32748 2020-08-06  Wilmington  33.780016 -118.262509   16.082444
# 32988    32988 2020-08-07  Wilmington  33.780016 -118.262509   16.181496
# 33228    33228 2020-08-08  Wilmington  33.780016 -118.262509   14.982024
#
#        Risk-Level  index_y  RS_change_7    index  RS_change_30  \
# 1429            2      NaN          NaN      NaN           NaN
# 1669            2      NaN          NaN      NaN           NaN
# 1909            1      NaN          NaN      NaN           NaN
# 2149            0      NaN          NaN      NaN           NaN
# 2389            0      NaN          NaN      NaN           NaN
# 5029            1      NaN          NaN      NaN           NaN
# 7579            1      NaN          NaN      NaN           NaN
# 8054            1      NaN          NaN      NaN           NaN
# 8294            1      NaN          NaN      NaN           NaN
# 8534            1      NaN          NaN      NaN           NaN
# 8774            1      NaN          NaN      NaN           NaN
# 9014            2      NaN          NaN      NaN           NaN
# 9254            2      NaN          NaN      NaN           NaN
# 2629            2      NaN          NaN      NaN           NaN
# 2869            2      NaN          NaN      NaN           NaN
# 3109            2      NaN          NaN      NaN           NaN
# 3349            2      NaN          NaN      NaN           NaN
# 3589            2      NaN          NaN      NaN           NaN
# 3829            2      NaN          NaN      NaN           NaN
# 4069            3      NaN          NaN      NaN           NaN
# 4309            3      NaN          NaN      NaN           NaN
# 4549            2      NaN          NaN      NaN           NaN
# 4789            2      NaN          NaN      NaN           NaN
# 5258            2      NaN          NaN      NaN           NaN
# 5487            2      NaN          NaN      NaN           NaN
# 5716            2      NaN          NaN      NaN           NaN
# 5945            2      NaN          NaN      NaN           NaN
# 6175            2      NaN          NaN      NaN           NaN
# 6406            2      NaN          NaN      NaN           NaN
# 6639            2      NaN          NaN      NaN           NaN
# 6872            2      NaN          NaN      NaN           NaN
# 7105            2      NaN          NaN      NaN           NaN
# 7339            2      NaN          NaN      NaN           NaN
# 7814            2      NaN          NaN      NaN           NaN
# 9490            2      NaN          NaN      NaN           NaN
# 12126           3      NaN          NaN      NaN           NaN
# 14762           3      NaN          NaN      NaN           NaN
# 15479           3      NaN          NaN      NaN           NaN
# 15717           2      NaN          NaN      NaN           NaN
# 15956           1      NaN          NaN      NaN           NaN
# 16196           0      NaN          NaN      NaN           NaN
# 16436           0      NaN          NaN      NaN           NaN
# 16676           0      NaN          NaN      NaN           NaN
# 9730            1      NaN          NaN      NaN           NaN
# 9970            1      NaN          NaN      NaN           NaN
# 10210           2      NaN          NaN      NaN           NaN
# 10450           2      NaN          NaN      NaN           NaN
# 10690           2      NaN          NaN      NaN           NaN
# 10930           3      NaN          NaN      NaN           NaN
# 11170           3      NaN          NaN      NaN           NaN
# 11410           3      NaN          NaN      NaN           NaN
# 11650           3      NaN          NaN      NaN           NaN
# 11890           3      NaN          NaN      NaN           NaN
# 12366           3      NaN          NaN      NaN           NaN
# 12606           3      NaN          NaN      NaN           NaN
# 12846           3      NaN          NaN      NaN           NaN
# 13086           3      NaN          NaN      NaN           NaN
# 13326           3      NaN          NaN      NaN           NaN
# 13566           3      NaN          NaN      NaN           NaN
# 13806           3      NaN          NaN      NaN           NaN
# 14046           3      NaN          NaN      NaN           NaN
# 14286           3      NaN          NaN      NaN           NaN
# 14526           3      NaN          NaN      NaN           NaN
# 15002           3      NaN          NaN      NaN           NaN
# 15242           3      NaN          NaN      NaN           NaN
# 16916           2      NaN          NaN      NaN           NaN
# 19556           0      NaN          NaN      NaN           NaN
# 22196           0      NaN          NaN      NaN           NaN
# 22676           2      NaN          NaN      NaN           NaN
# 22916           3      NaN          NaN      NaN           NaN
# 23156           3      NaN          NaN      NaN           NaN
# 23396           3      NaN          NaN      NaN           NaN
# 23636           3      NaN          NaN      NaN           NaN
# 23876           3      NaN          NaN      NaN           NaN
# 17156           3      NaN          NaN      NaN           NaN
# 17396           3      NaN          NaN      NaN           NaN
# 17636           3      NaN          NaN      NaN           NaN
# 17876           3      NaN          NaN      NaN           NaN
# 18116           2      NaN          NaN      NaN           NaN
# 18356           2      NaN          NaN      NaN           NaN
# 18596           3      NaN          NaN      NaN           NaN
# 18836           3      NaN          NaN      NaN           NaN
# 19076           3      NaN          NaN      NaN           NaN
# 19316           3      NaN          NaN      NaN           NaN
# 19796           3      NaN          NaN      NaN           NaN
# 20036           3      NaN          NaN      NaN           NaN
# 20276           3      NaN          NaN      NaN           NaN
# 20516           3      NaN          NaN      NaN           NaN
# 20756           3      NaN          NaN      NaN           NaN
# 20996           3      NaN          NaN      NaN           NaN
# 21236           3      NaN          NaN      NaN           NaN
# 21476           3      NaN          NaN      NaN           NaN
# 21716           3      NaN          NaN      NaN           NaN
# 21956           3      NaN          NaN      NaN           NaN
# 22436           3      NaN          NaN      NaN           NaN
# 24116           3      NaN          NaN      NaN           NaN
# 26752           3      NaN          NaN      NaN           NaN
# 29388           3      NaN          NaN      NaN           NaN
# 30108           3      NaN          NaN      NaN           NaN
# 30348           3      NaN          NaN      NaN           NaN
# 30588           3      NaN          NaN      NaN           NaN
# 30828           3      NaN          NaN      NaN           NaN
# 31068           3      NaN          NaN      NaN           NaN
# 31308           3      NaN          NaN      NaN           NaN
# 24356           3      NaN          NaN      NaN           NaN
# 24596           3      NaN          NaN      NaN           NaN
# 24836           3      NaN          NaN      NaN           NaN
# 25076           3      NaN          NaN      NaN           NaN
# 25316           3      NaN          NaN      NaN           NaN
# 25556           3      NaN          NaN      NaN           NaN
# 25795           3      NaN          NaN      NaN           NaN
# 26034           3      NaN          NaN      NaN           NaN
# 26273           3      NaN          NaN      NaN           NaN
# 26512           3      NaN          NaN      NaN           NaN
# 26991           3      NaN          NaN      NaN           NaN
# 27231           3      NaN          NaN      NaN           NaN
# 27470           3      NaN          NaN      NaN           NaN
# 27709           3      NaN          NaN      NaN           NaN
# 27948           3      NaN          NaN      NaN           NaN
# 28188           3      NaN          NaN      NaN           NaN
# 28428           3      NaN          NaN      NaN           NaN
# 28668           3      NaN          NaN      NaN           NaN
# 28908           3      NaN          NaN      NaN           NaN
# 29148           3      NaN          NaN      NaN           NaN
# 29628           3      NaN          NaN      NaN           NaN
# 29868           3      NaN          NaN      NaN           NaN
# 31548           3      NaN          NaN      NaN           NaN
# 31788           3      NaN          NaN      NaN           NaN
# 32028           3      NaN          NaN      NaN           NaN
# 32268           3      NaN          NaN      NaN           NaN
# 32508           3      NaN          NaN      NaN           NaN
# 32748           3      NaN          NaN      NaN           NaN
# 32988           3      NaN          NaN      NaN           NaN
# 33228           3  33228.0    11.858558  33228.0      6.087471
#
#        Rolling Average 7 Days  Rolling Average 30 Days
# 1429                 1.955186                 1.955186
# 1669                 1.577954                 1.577954
# 1909                 1.199041                 1.199041
# 2149                 0.910110                 0.910110
# 2389                 0.745253                 0.745253
# 5029                 0.676195                 0.676195
# 7579                 0.646323                 0.646323
# 8054                 0.426794                 0.617843
# 8294                 0.301135                 0.584872
# 8534                 0.292802                 0.564674
# 8774                 0.381537                 0.573745
# 9014                 0.513927                 0.610312
# 9254                 0.640829                 0.657152
# 2629                 0.743772                 0.695048
# 2869                 0.834729                 0.719056
# 3109                 0.936979                 0.738919
# 3349                 1.059141                 0.768278
# 3589                 1.188053                 0.812643
# 3829                 1.311242                 0.868550
# 4069                 1.427158                 0.926654
# 4309                 1.552180                 0.980758
# 4549                 1.685483                 1.026555
# 4789                 1.799191                 1.061610
# 5258                 1.857160                 1.085868
# 5487                 1.841585                 1.100747
# 5716                 1.774118                 1.112356
# 5945                 1.695703                 1.126037
# 6175                 1.633640                 1.143979
# 6406                 1.600882                 1.165186
# 6639                 1.594142                 1.185868
# 6872                 1.600699                 1.177018
# 7105                 1.612160                 1.188263
# 7339                 1.610808                 1.219993
# 7814                 1.598707                 1.265117
# 9490                 1.605556                 1.318135
# 12126                1.660692                 1.378602
# 14762                1.773472                 1.448869
# 15479                1.894128                 1.519396
# 15717                1.946276                 1.572129
# 15956                1.877484                 1.589753
# 16196                1.683435                 1.568893
# 16436                1.443957                 1.535142
# 16676                1.137537                 1.494501
# 9730                 0.816444                 1.465826
# 9970                 0.565147                 1.456494
# 10210                0.458696                 1.460530
# 10450                0.546980                 1.470248
# 10690                0.807957                 1.480204
# 10930                1.110144                 1.488219
# 11170                1.433923                 1.496079
# 11410                1.731121                 1.507579
# 11650                2.008632                 1.531895
# 11890                2.296627                 1.576598
# 12366                2.605411                 1.644840
# 12606                2.933054                 1.734880
# 12846                3.276734                 1.838829
# 13086                3.628817                 1.947139
# 13326                3.954970                 2.049223
# 13566                4.196615                 2.137566
# 13806                4.346897                 2.218908
# 14046                4.468416                 2.313974
# 14286                4.627220                 2.438394
# 14526                4.805027                 2.584147
# 15002                4.863165                 2.708846
# 15242                4.664870                 2.763063
# 16916                4.194419                 2.728769
# 19556                3.590723                 2.642933
# 22196                2.941908                 2.558456
# 22676                2.345611                 2.531572
# 22916                1.880814                 2.584924
# 23156                1.630560                 2.696508
# 23396                1.678744                 2.817846
# 23636                2.031143                 2.937278
# 23876                2.548300                 3.047032
# 17156                3.091014                 3.147825
# 17396                3.478999                 3.236309
# 17636                3.602294                 3.297831
# 17876                3.474775                 3.318766
# 18116                3.196224                 3.304598
# 18356                2.916089                 3.283116
# 18596                2.775285                 3.290671
# 18836                2.857975                 3.346005
# 19076                3.178670                 3.442119
# 19316                3.669358                 3.546085
# 19796                4.224708                 3.620152
# 20036                4.711305                 3.639332
# 20276                4.997202                 3.602406
# 20516                5.011829                 3.537271
# 20756                4.795039                 3.485638
# 20996                4.531977                 3.485305
# 21236                4.465167                 3.545327
# 21476                4.761565                 3.651499
# 21716                5.397209                 3.777507
# 21956                6.170202                 3.907381
# 22436                6.828868                 4.042204
# 24116                7.190424                 4.184705
# 26752                7.197906                 4.326981
# 29388                6.906442                 4.470385
# 30108                6.432094                 4.605012
# 30348                5.940506                 4.724769
# 30588                5.615368                 4.837170
# 30828                5.597080                 4.956482
# 31068                5.951370                 5.099425
# 31308                6.612269                 5.275240
# 24356                7.415089                 5.479335
# 24596                8.147280                 5.694278
# 24836                8.623317                 5.896341
# 25076                8.745019                 6.066894
# 25316                8.509512                 6.196250
# 25556                7.976516                 6.280191
# 25795                7.237665                 6.316462
# 26034                6.417063                 6.309789
# 26273                5.652656                 6.271541
# 26512                5.083333                 6.226268
# 26991                4.795286                 6.200029
# 27231                4.778354                 6.211894
# 27470                4.966172                 6.272951
# 27709                5.227856                 6.366869
# 27948                5.435237                 6.459169
# 28188                5.531024                 6.504652
# 28428                5.551121                 6.479658
# 28668                5.631940                 6.403116
# 28908                5.859299                 6.319715
# 29148                6.158712                 6.270270
# 29628                6.346720                 6.254367
# 29868                6.248048                 6.239281
# 31548                5.897058                 6.201121
# 31788                5.520642                 6.156304
# 32028                5.414699                 6.165724
# 32268                5.794190                 6.285575
# 32508                6.684973                 6.519844
# 32748                8.000974                 6.815276
# 32988                9.607102                 7.092285
# 33228               11.301181                 7.295201

# %%
# This function calculates trend of the Risk-Score at the most current data.
# Input:  length1, length2:    these parameters define the windows Risk Score differences
#         rolling_length:      window of the rolling average calculation
#         rolling_diff_length: window used to calculate the rolling average difference
# Output: recent:             this new dataframe contains list of all regions with calculated Risk Score Trends on the most current data

def rs_trend_summary(length1,length2,rolling_length,rolling_diff_length):
    
    #intializing variables
    recent = pd.DataFrame()
    df_recent_1= pd.DataFrame()
    df_recent_2= pd.DataFrame()
    recent
    
    df_new=df.copy()
    regions = df_new['Region'].unique()
#     recent['Region']=regions
#     recent['Date']=recent['Region']
    
    
    for region in regions:
        df_region = df_new[df_new['Region']==region].sort_values('Time Stamp')
        
        recent_date = max(df_region['Time Stamp'])
#         recent.loc[recent['Region']=='Alhambra','Date'] = recent_date
        
        length1_bef = pd.to_datetime(recent_date) - dt.timedelta(days=length1)
        length2_bef = pd.to_datetime(recent_date) - dt.timedelta(days=length2)

        df_1_before = df_region[df_region['Time Stamp'] == length1_bef]
        df_2_before = df_region[df_region['Time Stamp'] == length2_bef]
        df_recent = df_region[df_region['Time Stamp']==recent_date]
        

        string1= "RS_change_{}_Days".format(length1)
        string2= "RS_change_{}_Days".format(length2)
        
        if not df_1_before['Risk-Score'].empty:
            df_recent[string1] = df_recent['Risk-Score'].iloc[0]-df_1_before['Risk-Score'].iloc[0]
        else:
            df_recent[string1] = df_recent['Risk-Score'].iloc[0]

        if not df_2_before['Risk-Score'].empty:
            df_recent[string2] = df_recent['Risk-Score'].iloc[0]-df_2_before['Risk-Score'].iloc[0]
        else:
            df_recent[string2] = df_recent['Risk-Score'].iloc[0]
        
        
        
        #Rolling Avreage
        rolling_rs = df_region['Risk-Score'].rolling(rolling_length, min_periods=1).mean()
        
        recent_rolling = rolling_rs.iloc[-1]
        length3 = 0 - rolling_diff_length -1
        past_rolling = rolling_rs.iloc[length3]
        
        rolling_diff = recent_rolling - past_rolling
        
            
        
        df_recent["Recent_Rolling_Average"] = recent_rolling
        df_recent["Past_Rolling_Average"] = past_rolling
        df_recent["Rolling_Difference"] = rolling_diff
        
        threshhold=1/7

        if rolling_diff > threshhold:
            df_recent['Risk_Trend_Abs'] = 'Red'
        if (rolling_diff < threshhold) & (rolling_diff > -threshhold):
            df_recent['Risk_Trend_Abs'] = 'Yellow'
        if rolling_diff < -threshhold:
            df_recent['Risk_Trend_Abs'] = 'Green'
        
        percent_change = (rolling_diff)*100/past_rolling
        percent_threshhold = 5
        df_recent['percent_change']=round(percent_change)
        
        if percent_change > percent_threshhold:
            df_recent['Risk_Trend_%'] = 'Red'
        if (percent_change < percent_threshhold) & (percent_change > -percent_threshhold):
            df_recent['Risk_Trend_%'] = 'Yellow'
        if percent_change < -percent_threshhold:
            df_recent['Risk_Trend_%'] = 'Green'
        
#         if rolling_diff > threshhold:
#             df_recent['Risk_Trend_Abs'] = 'Red'
#         if (rolling_diff < threshhold) & (rolling_diff > -threshhold):
#             df_recent['Risk_Trend_Abs'] = 'Yellow'
#         if rolling_diff < -threshhold:
#             df_recent['Risk_Trend_Abs'] = 'Grenn'
        
        
        recent = recent.append(df_recent)
        
    return recent

# %%
a = rs_trend_summary(3,14,12,1)
a=a.drop(['index','Time Stamp','Latitude', 'Longitude','RS_change_3_Days','RS_change_14_Days'], axis=1)

a.head(20)
# Out:
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:68: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 Region  Risk-Score  Risk-Level  Recent_Rolling_Average  \
# 32995         Alhambra    4.015684           3            3.225464e+00
# 33000          Arcadia    3.242215           3            3.108070e+00
# 33014    Beverly Hills    2.586989           3            1.073646e+00
# 33016    Boyle Heights   10.717536           3            1.199253e+01
# 33025           Carson    0.510680           1            1.991776e+00
# 33046      Diamond Bar    2.817990           3            2.751848e+00
# 33059           Encino    0.820792           1            1.400614e+00
# 33065          Gardena    6.767975           3            4.304799e+00
# 33067         Glendale    8.999677           3            1.222087e+01
# 33068         Glendora    0.000000           0            1.934794e-01
# 33070    Granada Hills    7.091290           3            4.977538e+00
# 33090        Inglewood    9.495442           3            9.700354e+00
# 33096        La Mirada    0.433272           1            3.585446e-01
# 33104        Lancaster    0.614993           1            5.721866e-01
# 33118  Manhattan Beach    0.181240           1            8.724221e-01
# 33122          Melrose    3.832395           3            4.034593e+00
# 33132       Northridge    5.994005           3            4.044450e+00
# 33161        San Dimas    0.000000           0            2.457525e-17
# 33165        San Pedro    0.273344           1            3.428705e-01
# 33168     Santa Monica    2.932503           3            2.151422e+00
#
#        Past_Rolling_Average  Rolling_Difference Risk_Trend_Abs  \
# 32995          3.648439e+00           -0.422975          Green
# 33000          2.983728e+00            0.124342         Yellow
# 33014          8.580636e-01            0.215582            Red
# 33016          1.315577e+01           -1.163239          Green
# 33025          2.143074e+00           -0.151298          Green
# 33046          2.738537e+00            0.013311         Yellow
# 33059          1.520604e+00           -0.119990         Yellow
# 33065          4.257226e+00            0.047572         Yellow
# 33067          1.262008e+01           -0.399208          Green
# 33068          2.150592e-01           -0.021580         Yellow
# 33070          4.740719e+00            0.236818            Red
# 33090          1.011239e+01           -0.412032          Green
# 33096          3.224385e-01            0.036106         Yellow
# 33104          5.679592e-01            0.004227         Yellow
# 33118          9.030191e-01           -0.030597         Yellow
# 33122          4.262946e+00           -0.228353          Green
# 33132          4.149945e+00           -0.105495         Yellow
# 33161          2.457525e-17            0.000000         Yellow
# 33165          3.200918e-01            0.022779         Yellow
# 33168          2.142902e+00            0.008520         Yellow
#
#        percent_change Risk_Trend_%
# 32995           -12.0        Green
# 33000             4.0       Yellow
# 33014            25.0          Red
# 33016            -9.0        Green
# 33025            -7.0        Green
# 33046             0.0       Yellow
# 33059            -8.0        Green
# 33065             1.0       Yellow
# 33067            -3.0       Yellow
# 33068           -10.0        Green
# 33070             5.0       Yellow
# 33090            -4.0       Yellow
# 33096            11.0          Red
# 33104             1.0       Yellow
# 33118            -3.0       Yellow
# 33122            -5.0        Green
# 33132            -3.0       Yellow
# 33161             0.0       Yellow
# 33165             7.0          Red
# 33168             0.0       Yellow

# %%
city='San Pedro'
plot_rs(city,12, 7)
# Out:
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
calc_risk_trend(city, 12, 7)
# Out:
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kwonk\anaconda3\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      index_x Time Stamp    Region   Latitude   Longitude  Risk-Score  \
# 493      493 2020-03-23  Florence  33.974159 -118.243286    1.100767
# 606      606 2020-03-24  Florence  33.974159 -118.243286    1.105979
# 732      732 2020-03-25  Florence  33.974159 -118.243286    0.801222
# 864      864 2020-03-26  Florence  33.974159 -118.243286    0.282801
#
#      Risk-Level  index_y  RS_change_12  index  RS_change_7  \
# 493           2      NaN           NaN    NaN          NaN
# 606           2      NaN           NaN    NaN          NaN
# 732           1      NaN           NaN    NaN          NaN
# 864           1    864.0      0.282801  864.0     0.282801
#
#      Rolling Average 12 Days  Rolling Average 7 Days
# 493                 1.100767                1.100767
# 606                 1.103373                1.103373
# 732                 1.002656                1.002656
# 864                 0.822692                0.822692
